# %% [markdown]
# # Dataset Background
#
# this is a transactional data set which contains all the transactions occurring between 01/02/2010 and 09/12/2011 for a UK-based and registered non-store online retail.The company mainly sells unique all- occasion gifts. many customers of the company are wholesalers.
#  Attribute

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df= pd.read_csv(r"C:\Users\Abraham okotore\Documents\Data2.csv")

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#Let's create a new column called 'TotalPrice' that represents the total price for each transaction 
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

# %%
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

# %%
#Now let summarise the statistics for the numerical column
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID     TotalPrice
# count  541909.000000  541909.000000  406829.000000  541909.000000
# mean        9.552250       4.611114   15287.690570      17.987795
# std       218.081158      96.759853    1713.600303     378.810824
# min    -80995.000000  -11062.060000   12346.000000 -168469.600000
# 25%         1.000000       1.250000   13953.000000       3.400000
# 50%         3.000000       2.080000   15152.000000       9.750000
# 75%        10.000000       4.130000   16791.000000      17.400000
# max     80995.000000   38970.000000   18287.000000  168469.600000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
#  8   TotalPrice   541909 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 37.2+ MB

# %%
missing_description = df.loc[df.Description.isnull()]
missing_description
# Out:
#        InvoiceNo StockCode Description  Quantity       InvoiceDate  UnitPrice  \
# 622       536414     22139         NaN        56  12/01/2010 11:52        0.0
# 1970      536545     21134         NaN         1  12/01/2010 14:32        0.0
# 1971      536546     22145         NaN         1  12/01/2010 14:33        0.0
# 1972      536547     37509         NaN         1  12/01/2010 14:33        0.0
# 1987      536549    85226A         NaN         1  12/01/2010 14:34        0.0
# ...          ...       ...         ...       ...               ...        ...
# 535322    581199     84581         NaN        -2  12/07/2011 18:26        0.0
# 535326    581203     23406         NaN        15  12/07/2011 18:31        0.0
# 535332    581209     21620         NaN         6  12/07/2011 18:35        0.0
# 536981    581234     72817         NaN        27  12/08/2011 10:33        0.0
# 538554    581408     85175         NaN        20  12/08/2011 14:06        0.0
#
# ...

# %%
missing_description.UnitPrice.value_counts()
# Out:
# 0.0    1454
# Name: UnitPrice, dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# TotalPrice     0
# dtype: int64

# %%
canceled_orders.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-4a4952fc6a71> in <module>
# ----> 1 canceled_orders.info()
#
# NameError: name 'canceled_orders' is not defined

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# ...

# %%
df.to_csv('CleanedData.csv')

# %%
# We can answer this question by grouping the data by country and calculating the mean for the 'TotalPrice' and 'Quantity' columns
mean_price_by_country = df('Country')['TotalPrice'].mean()
mean_quantity_by_country = df('Country')['Quantity'].mean()
print(mean_price_by_country.sort_values(ascending=False).head(10))
print(mean_quantity_by_country.sort_values(ascending=False).head(10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-e655d9fca287> in <module>
#       1 # We can answer this question by grouping the data by country and calculating the mean for the 'TotalPrice' and 'Quantity' columns
# ----> 2 mean_price_by_country = df('Country')['TotalPrice'].mean()
#       3 mean_quantity_by_country = df('Country')['Quantity'].mean()
#       4 print(mean_price_by_country.sort_values(ascending=False).head(10))
#       5 print(mean_quantity_by_country.sort_values(ascending=False).head(10))
#
# TypeError: 'DataFrame' object is not callable

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# ...

# %%
country_group = df.groupby('Country')
mean_price_by_country = country_group['TotalPrice'].mean()
print(mean_price_by_country)
# Out:
# Country
# Australia               108.877895
# Austria                  25.322494
# Bahrain                  32.258824
# Belgium                  19.773301
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          26.499063
# Cyprus                   20.813971
# Czech Republic           23.590667
# Denmark                  48.247147
# EIRE                     33.438239
# European Community       21.176230
# Finland                  32.124806
# France                   23.167217
# Germany                  23.348943
# Greece                   32.263836
# Iceland                  23.681319
# Israel                   27.977000
# Italy                    21.034259
# Japan                    98.716816
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    19.728110
# Netherlands             120.059696
# Norway                   32.378877
# Poland                   21.152903
# ...

# %% [markdown]
# What is the average transaction value and quantity per transaction, and how do they vary by country?

# %%
mean_price_by_country.plot(kind='bar')
plt.show()

# %%
#We can answer this question by grouping the data by country and calculating the men an for the the totalprice and quality  columns

mean_price_by_country = df.groupby('Country')['TotalPrice'].mean()
mean_quantity_by_country=df.groupby('Country')['Quality']

# %%
#top ten Countries 
df_countries=df[['Country', 'TotalPrice']]
#next I group the by country and sum the total price for each country
df_countries=df_countries.groupby('Country').sum()
#finally I sort the data by total price for each country
df_countries= df_countries.sort_values('TotalPrice', ascending = False)
df_countries
print(df_countries.head(10))
#seaborn using horizontal barplot
sns.barplot(x='TotalPrice', y='Country', data=df_countries.reset_index().head(10), orient='h')
plt.show()
# Out:
#                   TotalPrice
# Country
# United Kingdom  6.767873e+06
# Netherlands     2.846615e+05
# EIRE            2.502852e+05
# Germany         2.216982e+05
# France          1.967128e+05
# Australia       1.370773e+05
# Switzerland     5.573940e+04
# Spain           5.477458e+04
# Belgium         4.091096e+04
# Sweden          3.659591e+04

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# ...

# %% [raw]
# 1. what is the overall trends in the total sales over time ?

# %%
#  I answer this question by first creating a new column called total price for each transaction

df['TotalPrice']= df['Quantity'] * df ['UnitPrice']
#Next group the data by invoice date and sum the total price for each date
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

df['Year']= df['InvoiceDate'].dt.year

total_sales_by_year =df.groupby('Year')['TotalPrice'].sum()
#Now we can use the seaborn to plot the total sale over time 
sns.lineplot(x=total_sales_by_year.index, y=total_sales_by_year.values)   
plt.title('Total Sales over time')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.show()
# Out:
# <ipython-input-48-ca41a3ac4472>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalPrice']= df['Quantity'] * df ['UnitPrice']
# <ipython-input-48-ca41a3ac4472>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
# <ipython-input-48-ca41a3ac4472>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# what is the average transaction value and quantity per transaction, and how they vary by country?

# %%
mean_price_by_Country=df.groupby('Country')['TotalPrice'].mean()
mean_quantity_by_country=df.groupby('Country')['Quantity'].mean()
print(mean_price_by_country.sort_values(ascending= False).head(6))
print(mean_quantity_by_country.sort_values(ascending= False).head(6))
#Now, we can use seaborn to plot the mean then presenting the visual 
sns.lineplot(x=mean_price_by_country.index, y=mean_price_by_country.values, label = 'transaction Value')
sns.lineplot(x=mean_quantity_by_country.index, y=mean_quantity_by_country.values, label = 'transaction Quality')
# Out:
# Country
# Netherlands    120.059696
# Australia      108.877895
# Japan           98.716816
# Sweden          79.211926
# Denmark         48.247147
# Lithuania       47.458857
# Name: TotalPrice, dtype: float64
# Country
# Netherlands    84.406580
# Sweden         77.136364
# Japan          70.441341
# Australia      66.444003
# Singapore      22.855895
# Denmark        21.048843
# Name: Quantity, dtype: float64
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# How does the number of transactions and the total sales vary by country?

# %%
#we can answer this question by grouping the data by country and counting thr number of transaction and summ
#ing the total sales for each country
num_transactions_by_country =df.groupby('Country')['InvoiceNo'].nunique()
total_sales_by_country = df.groupby('Country')['TotalPrice'].sum()

#Now, we can print the number of transactions and totals sales for each country
print(num_transactions_by_country.sort_values(ascending=False).head(10))
print(total_sales_by_country.sort_values(ascending=False).head(10))
#Set the style for the plots
sns.set_style('darkgrid')
#Create the figure and the subplots
fig, ax =plt.subplots(nrows=1, ncols=2, figsize =(10,5))
#Plot the number of transactions per country
sns.barplot(x=num_transactions_by_country.sort_values(ascending=False).head(10),
y=num_transactions_by_country.sort_values(ascending= False).head(10).index, ax=ax[0], orient ='h')
ax[0].set_title('Number of Transactions by Country')
   
#Plot the total sales per country 
sns.barplot(x=total_sales_by_country.sort_values(ascending=False).head(10),
y=total_sales_by_country.sort_values(ascending= False).head(10).index, ax=ax[1], orient ='h')
ax[1].set_title('Total Sales by Country')
   
#Show the plot
plt.show()
# Out:
# Country
# United Kingdom    19857
# Germany             603
# France              458
# EIRE                319
# Belgium             119
# Spain               105
# Netherlands         101
# Switzerland          71
# Portugal             70
# Australia            69
# Name: InvoiceNo, dtype: int64
# Country
# United Kingdom    6.767873e+06
# Netherlands       2.846615e+05
# EIRE              2.502852e+05
# Germany           2.216982e+05
# France            1.967128e+05
# Australia         1.370773e+05
# Switzerland       5.573940e+04
# Spain             5.477458e+04
# Belgium           4.091096e+04
# Sweden            3.659591e+04
# Name: TotalPrice, dtype: float64

# %%
#Which products have the highest sales,and which countries?
#We can answer this question by grouping the data by product and country and summing the total sales for each group
Product_sales_by_country=df.groupby(['Description', 'Country'])['TotalPrice'].sum()
print(Product_sales_by_country.sort_values(ascending=False). head(10))
#Now, we can use seaborn tov plot the top 10 products with this highest sales, along with the country where they had the highest sales
top_products= Product_sales_by_country.sort_values(ascending=False).head(10).reset_index()
sns.barplot(x='Country', y='TotalPrice', hue ='Description', data=top_products)
plt.title('Highest product sales by product')
plt.xlabel('Country')
plt.ylabel('Total Sales')
plt.show()
# Out:
# Description                         Country
# REGENCY CAKESTAND 3 TIER            United Kingdom    103122.85
# WHITE HANGING HEART T-LIGHT HOLDER  United Kingdom     88313.95
# JUMBO BAG RED RETROSPOT             United Kingdom     75416.67
# PARTY BUNTING                       United Kingdom     61952.58
# ASSORTED COLOUR BIRD ORNAMENT       United Kingdom     52314.87
# CHILLI LIGHTS                       United Kingdom     45155.61
# PICNIC BASKET WICKER 60 PIECES      United Kingdom     39619.50
# PAPER CHAIN KIT 50'S CHRISTMAS      United Kingdom     39596.73
# BLACK RECORD COVER FRAME            United Kingdom     37799.42
# WOOD BLACK BOARD ANT WHITE FINISH   United Kingdom     33408.76
# Name: TotalPrice, dtype: float64

# %% [markdown]
# Do some customers have higher average transaction values or quantities than others?

# %%
#We can answer this question by grouping the data by customer and calculating the mean fot the 'totalPrice' and 
#'Quantity' columns
mean_price_by_product = df.groupby('StockCode')['TotalPrice'].mean()
mean_quantity_by_customer = df.groupby('StockCode')['Quantity'].mean()
#Now, I put the num_customers_byyear_country ans retention_rate_by_year_and_country
df_avgtranq = pd.concat([mean_quantity_by_customer, mean_quantity_by_customer], axis=1)
df_avgtranq.columns = ['avgCustomerPrice', 'avgCustomerQuantity']

print(df_avgtranq.head())
sns.scatterplot(x='avgCustomerPrice', y='avgCustomerQuantity', data=df_avgtranq)
plt.show()
# Out:
#            avgCustomerPrice  avgCustomerQuantity
# StockCode
# 10002             16.795918            16.795918
# 10080             13.857143            13.857143
# 10120              6.433333             6.433333
# 10123C             1.666667             1.666667
# 10124A             3.200000             3.200000

# %% [markdown]
#  What are the most popular products by sales?

# %%
# Group the data by product and sum the total sales for each product
product_sales = df.groupby('Description')['TotalPrice'].sum()

# Sort the data by total sales and select the top 10 products
top_products = product_sales.sort_values(ascending=False).head(10)
print(top_products)

# Plot the data as a horizontal bar chart
top_products.plot(kind='barh')
plt.title("Most popular product by sales")
plt.xlabel("Total Price")
plt.show()
# Out:
# Description
# REGENCY CAKESTAND 3 TIER              132870.40
# WHITE HANGING HEART T-LIGHT HOLDER     93823.85
# JUMBO BAG RED RETROSPOT                83236.76
# PARTY BUNTING                          67687.53
# POSTAGE                                66710.24
# ASSORTED COLOUR BIRD ORNAMENT          56499.22
# RABBIT NIGHT LIGHT                     51137.80
# CHILLI LIGHTS                          45936.81
# PAPER CHAIN KIT 50'S CHRISTMAS         41500.48
# PICNIC BASKET WICKER 60 PIECES         39619.50
# Name: TotalPrice, dtype: float64

# %% [markdown]
#  What is the overall customer retention rate, and how does it vary by country or other factors?

# %%
# Now, we'll group the data by year and sum the total sales for each year
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['Year'] = df['InvoiceDate'].dt.year
total_sales_by_year = df.groupby('Year')['TotalPrice'].sum()

# Next, we'll group the data by month and sum the total sales for each month
df['Month'] = df['InvoiceDate'].dt.month
total_sales_by_month = df.groupby('Month')['TotalPrice'].sum()

# Next, we'll group the data by week and count the number of transactions for each week
df['Week'] = df['InvoiceDate'].dt.week
num_transactions_by_week = df.groupby('Week')['InvoiceNo'].nunique()

# Next, we'll group the data by day and count the number of transactions for each day
df['Day'] = df['InvoiceDate'].dt.day
num_transactions_by_day = df.groupby('Day')['InvoiceNo'].nunique()

# Finally, we'll group the data by hour and count the number of transactions for each hour
df['Hour'] = df['InvoiceDate'].dt.hour
num_transactions_by_hour = df.groupby('Hour')['InvoiceNo'].nunique()

# Create a list of dataframes to loop through
dataframes = [total_sales_by_year, total_sales_by_month, num_transactions_by_week, num_transactions_by_day, num_transactions_by_hour]

# Create a list of titles for each dataframe
titles = ['Total Sales by Year', 'Total Sales by Month', 'Number of Transactions by Week', 'Number of Transactions by Day', 'Number of Transactions by Hour']
# Out:
# <ipython-input-31-a60dee54b4c8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
# <ipython-input-31-a60dee54b4c8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['InvoiceDate'].dt.year
# <ipython-input-31-a60dee54b4c8>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#We can answer this question by counting the number of unique customers for each year and country and calculating the retention rate as a percentage
num_customers_by_year_and_country = df.groupby(['Year', 'Country'])['CustomerID'].nunique()
retention_rate_by_year_and_country = num_customers_by_year_and_country.pct_change().fillna(0)

# Now, we'll put the num_customers_by_year_and_country and retention_rate_by_year_and_country data into a single dataframe
df_retention = pd.concat([num_customers_by_year_and_country, retention_rate_by_year_and_country], axis=1)
df_retention.columns = ['NumCustomers', 'RetentionRate']

# Finally, we'll sort the data in descending order by retention rate
df_retention = df_retention.sort_values(by='RetentionRate', ascending=False)
df_retention.head(10)
# Out:
#                      NumCustomers  RetentionRate
# Year Country
# 2011 United Kingdom          3835    1916.500000
# 2010 United Kingdom           871     434.500000
# 2011 Spain                     30      29.000000
# 2010 France                    15      14.000000
# 2011 Belgium                   25      11.500000
#      Finland                   12      11.000000
#      Denmark                    9       8.000000
#      France                    84       6.000000
# 2010 Portugal                   6       5.000000
# 2011 Italy                     13       3.333333
